# %%
import hftbacktest
import numpy as np
from hftbacktest.stats import LinearAssetRecord

recorder = np.load("glft_mm_max_pos_200.npz")["0"]

# %%
stats = (LinearAssetRecord(recorder).stats())
stats.plot()
stats.summary(pretty=True)
# Out:
# shape: (1, 11)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ start     ┆ end       ┆ SR        ┆ Sortino  ┆ … ┆ DailyTrad ┆ ReturnOve ┆ ReturnOve ┆ MaxPositi │
# │ ---       ┆ ---       ┆ ---       ┆ ---      ┆   ┆ ingValue  ┆ rMDD      ┆ rTrade    ┆ onValue   │
# │ datetime[ ┆ datetime[ ┆ f64       ┆ f64      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ μs]       ┆ μs]       ┆           ┆          ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2025-01-0 ┆ 2025-01-3 ┆ -2.189515 ┆ -2.93771 ┆ … ┆ 1.2812e6  ┆ -0.561574 ┆ -0.000037 ┆ 82588.975 │
# │ 2         ┆ 1         ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00:00:00  ┆ 23:59:50  ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# ...
